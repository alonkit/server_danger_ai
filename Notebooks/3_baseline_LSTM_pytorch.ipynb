# %%
import our_src.scinet as scient
import src.framework__test_bench as bench
import src.framework__data_set as ds

# %%
test_to_perform = (
    # Container CPU
    {"metric": "container_mem", "app": "kube-rbac-proxy", "prediction length": 20, "sub sample rate": 30, "data length limit": 84},
    # {"metric": "container_cpu", "app": "dns",             "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_cpu", "app": "collector",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Container Memory
    # {"metric": "container_mem", "app": "nmstate-handler", "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "coredns",         "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "keepalived",      "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Node Memory
    # {"metric": "node_mem",      "app": "moc/smaug",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "node_mem",      "app": "emea/balrog",     "prediction length": 16, "sub sample rate": 30, "data length limit": 30}
)

# %%
tb = bench.TestBench(
        class_to_test=scient.PytorchSCITester,
        path_to_data="../data/OperatreFirst_PrometheusData_AppLearner/OperatreFirst_PrometheusData_AppLearner/",
        tests_to_perform=test_to_perform
    )
tb.run_training_and_tests()
# Out:
# [TEST BENCH] Powering on test bench
# [TEST BENCH] testing metric='container_mem', app='kube-rbac-proxy'.
# [TEST BENCH] Fetching data for metric='container_mem', app='kube-rbac-proxy'.
# ['container_cpu_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_cpu_2022-04-30_16_00_00_to_2022-05-12_22_00_00.json', 'container_cpu_2022-05-12_22_00_00_to_2022-05-28_17_00_00.json', 'container_cpu_2022-05-28_17_00_00_to_2022-06-08_17_00_00.json', 'container_cpu_2022-06-08_17_00_00_to_2022-06-13_21_00_00.json', 'container_mem_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_mem_2022-04-30_16_00_00_to_2022-05-12_21_00_00.json', 'container_mem_2022-05-12_21_00_00_to_2022-05-28_14_00_00.json', 'container_mem_2022-05-28_14_00_00_to_2022-06-08_14_00_00.json', 'container_mem_2022-06-08_14_00_00_to_2022-06-13_21_00_00.json', 'node_mem_2022-05-28_10_00_00_to_2022-06-13_21_00_00.json']
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# [TEST BENCH] Throwing out data that is less than 42.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test.
# [TEST BENCH] Amount of train/test data is 284.
# [TEST BENCH] Making an instance of the class we want to test.
# [PytorchLSTMTester] model = SCINet(
#   (blocks1): EncoderTree(
#     (SCINet_Tree): SCINet_Tree(
#       (workingblock): LevelSCINet(
#         (interact): InteractorLevel(
#           (level): Interactor(
#             (split): Splitting()
#             (phi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (psi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (P): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (U): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#           )
#         )
#       )
#       (SCINet_Tree_odd): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#       (SCINet_Tree_even): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (projection1): Conv1d(40, 20, kernel_size=(1,), stride=(1,), bias=False)
#   (div_projection): ModuleList()
# )
# [PytorchLSTMTester] optimizer = Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     initial_lr: 0.0005
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0
# )
# [PytorchLSTMTester] optimizer = <torch.optim.lr_scheduler.ExponentialLR object at 0x7f62c54bd610>
# [PytorchLSTMTester] criterion = MSELoss()
# [TEST BENCH] Starting training loop.
# number of training samples = 14894
# Epoch 1 done. Epoch time was 24.88796877861023. Average loss for the batches in epoch is 0.10132914226773983
# Epoch 2 done. Epoch time was 24.770424842834473. Average loss for the batches in epoch is 0.007111231428211307
# Epoch 3 done. Epoch time was 24.632694959640503. Average loss for the batches in epoch is 0.0058730504987161815
# Epoch 4 done. Epoch time was 24.642003536224365. Average loss for the batches in epoch is 0.00545045565324136
# Epoch 5 done. Epoch time was 24.988908052444458. Average loss for the batches in epoch is 0.005208308303372959
# Epoch 6 done. Epoch time was 24.710349321365356. Average loss for the batches in epoch is 0.005051363448916171
# Epoch 7 done. Epoch time was 24.708311796188354. Average loss for the batches in epoch is 0.004913395826301094
# Epoch 8 done. Epoch time was 24.741225481033325. Average loss for the batches in epoch is 0.004812755427611073
# Epoch 9 done. Epoch time was 24.61888027191162. Average loss for the batches in epoch is 0.004716591414637752
# Epoch 10 done. Epoch time was 24.63841724395752. Average loss for the batches in epoch is 0.00462566119820567
# Epoch 11 done. Epoch time was 24.62389373779297. Average loss for the batches in epoch is 0.004559703174001206
# Epoch 12 done. Epoch time was 24.6505925655365. Average loss for the batches in epoch is 0.004488379720002892
# Epoch 13 done. Epoch time was 24.668327569961548. Average loss for the batches in epoch is 0.004436896071177728
# Epoch 14 done. Epoch time was 24.713173627853394. Average loss for the batches in epoch is 0.0043822784684278675
# Epoch 15 done. Epoch time was 24.742274045944214. Average loss for the batches in epoch is 0.004335642254675535
# Epoch 16 done. Epoch time was 24.71918511390686. Average loss for the batches in epoch is 0.004298751862008172
# Epoch 17 done. Epoch time was 24.717982053756714. Average loss for the batches in epoch is 0.0042604622770852285
# Epoch 18 done. Epoch time was 24.752434015274048. Average loss for the batches in epoch is 0.004221933327521329
# Epoch 19 done. Epoch time was 24.830106258392334. Average loss for the batches in epoch is 0.0041907372279392455
# Epoch 20 done. Epoch time was 24.721981287002563. Average loss for the batches in epoch is 0.004156326758925096
# Epoch 21 done. Epoch time was 24.73870086669922. Average loss for the batches in epoch is 0.004128378213637073
# Epoch 22 done. Epoch time was 24.767601251602173. Average loss for the batches in epoch is 0.004077827747283672
# Epoch 23 done. Epoch time was 24.65797448158264. Average loss for the batches in epoch is 0.004040023597514921
# Epoch 24 done. Epoch time was 24.678202867507935. Average loss for the batches in epoch is 0.003978786585091058
# Epoch 25 done. Epoch time was 24.687323570251465. Average loss for the batches in epoch is 0.0039081479911892295
# Epoch 26 done. Epoch time was 24.747901678085327. Average loss for the batches in epoch is 0.0038628480934274137
# Epoch 27 done. Epoch time was 24.57724928855896. Average loss for the batches in epoch is 0.0038229686044688165
# Epoch 28 done. Epoch time was 24.686453342437744. Average loss for the batches in epoch is 0.003775920804346164
# Epoch 29 done. Epoch time was 24.653099060058594. Average loss for the batches in epoch is 0.0037294233539101745
# Epoch 30 done. Epoch time was 24.69008207321167. Average loss for the batches in epoch is 0.003668403006388602
# [TEST BENCH] Training took 741.4935030937195 seconds.
# [TEST BENCH] Starting testing loop
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [3], in <cell line: 6>()
#       1 tb = bench.TestBench(
#       2         class_to_test=scient.PytorchSCITester,
#       3         path_to_data="../data/OperatreFirst_PrometheusData_AppLearner/OperatreFirst_PrometheusData_AppLearner/",
#       4         tests_to_perform=test_to_perform
#       5     )
# ----> 6 tb.run_training_and_tests()
#
# File ~/server_danger_ai/src/framework__test_bench.py:324, in TestBench.run_training_and_tests(self)
#     322     metric = dictionary["metric"]
#     323     print(self.__msg, f"testing metric='{metric}', app='{app}'.")
# --> 324     mse, precision, recall, f1, training_time, mase, mape = self.__do_one_test(dictionary=dictionary)
#     325     full_report += [(mse, precision, recall, f1, training_time, mase, mape)]
#     326 assert len(full_report) == len(self.__tests_to_perform)
#
# File ~/server_danger_ai/src/framework__test_bench.py:281, in TestBench.__do_one_test(self, dictionary)
#     279 print(self.__msg, f"Training took {training_time} seconds.")
#     280 print(self.__msg, "Starting testing loop")
# --> 281 mse, precision, recall, f1, mase, mape = self.__test_model(test=test, model=model)
#     282 self.__print_report(
#     283     metric=metric, app=app, mse=mse, precision=precision, recall=recall, f1=f1,
#     284     training_time=training_time, mase=mase, mape=mape
#     285 )
#     286 print(self.__msg, f"Done with metric='{metric}', app='{app}'")
#
# File ~/server_danger_ai/src/framework__test_bench.py:251, in TestBench.__test_model(self, test, model)
#     249 total_mape = 0
#     250 for i, test_sample in enumerate(test):
# --> 251     mse_here, precision, recall, f1, mase, mape = self.__give_one_test_to_model(
#     252         test_sample=test_sample, model=model, should_print=(i < 10)
#     253     )
#     254     total_mse += mse_here
#     255     total_precision += precision
#
# File ~/server_danger_ai/src/framework__test_bench.py:193, in TestBench.__give_one_test_to_model(self, test_sample, model, should_print)
#     191 # make sure the output is in the right format
#     192 assert isinstance(returned_ts_as_np_array, np.ndarray)
# --> 193 assert len(returned_ts_as_np_array) == how_much_to_predict
#     194 assert returned_ts_as_np_array.shape == (how_much_to_predict,)
#     195 # plot if needed
#
# AssertionError:

# %%
# %debug
